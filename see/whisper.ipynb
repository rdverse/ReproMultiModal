# %%
# !pip install botometer

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os 
import pandas as pd
import numpy as np
import ast
import botometer
from tweepy.auth import OAuthHandler
import tweepy

# %%
#for botometer - twitter
value = '5864dec497msh3dff20ee72f4cc9p10b426jsn8715d7234d4b'
rapidapi_key = value # now it's called rapidapi key

twitter_app_auth = {
'consumer_key': "rxfIchFI3wA8RStZmvgs0pUGw",
'consumer_secret' : "wVwOlDtAQfUI8ViLFYCk60NXRbb1cz07kAV4EQySoYdYTVJLK8",
'access_token' : "911810952386904064-TrAtnPStv4NT1j3NtrTtgAqWmtNG8NN",
'access_token_secret' : "ZJEzcAPKqXJ9Yo1puDvzznGZkUkQ6y0THKWdmKlGlycLh"
 }

# for getting user details
CONSUMER_KEY = "rxfIchFI3wA8RStZmvgs0pUGw"
CONSUMER_SECRET = "wVwOlDtAQfUI8ViLFYCk60NXRbb1cz07kAV4EQySoYdYTVJLK8"
OAUTH_TOKEN = "911810952386904064-TrAtnPStv4NT1j3NtrTtgAqWmtNG8NN"
OAUTH_TOKEN_SECRET = "ZJEzcAPKqXJ9Yo1puDvzznGZkUkQ6y0THKWdmKlGlycLh"

auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth , wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# %%
data = api.rate_limit_status()

# %%
data.keys()

# %%
data

# %%
df = pd.DataFrame()
for df_chunk in  pd.read_csv('drive/My Drive/altmetric_data/final.csv', chunksize =1000, encoding = 'utf-8'):
    df =df_chunk
    break

# %%
df = df[['']]
