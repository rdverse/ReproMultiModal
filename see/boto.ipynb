# %%
import botometer
value = '5864dec497msh3dff20ee72f4cc9p10b426jsn8715d7234d4b'
rapidapi_key = value # now it's called rapidapi key
twitter_app_auth = {
'consumer_key': "rxfIchFI3wA8RStZmvgs0pUGw",
'consumer_secret' : "wVwOlDtAQfUI8ViLFYCk60NXRbb1cz07kAV4EQySoYdYTVJLK8",
'access_token' : "911810952386904064-TrAtnPStv4NT1j3NtrTtgAqWmtNG8NN",
'access_token_secret' : "ZJEzcAPKqXJ9Yo1puDvzznGZkUkQ6y0THKWdmKlGlycLh"
 }
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# Check a single account by screen name
result = bom.check_account('UNESCO')
print(result)
# Check a single account by id
# result = bom.check_account(3326766226)
# print(result)
# Check a sequence of accounts
# accounts = ['@clayadavis', '@onurvarol', '@jabawack', '@UNESCO']
# for screen_name, result in bom.check_accounts_in(accounts):
# #     # Do stuff with `screen_name` and `result`
#     print(result)
# Out:
# {'cap': {'english': 0.0013611897321404152, 'universal': 0.002571043998532308}, 'categories': {'content': 0.3491761231837822, 'friend': 0.1506871410722809, 'network': 0.05626884453682943, 'sentiment': 0.1102544514170251, 'temporal': 0.18834180907135, 'user': 0.027817972609638725}, 'display_scores': {'content': 1.7, 'english': 0.2, 'friend': 0.8, 'network': 0.3, 'sentiment': 0.6, 'temporal': 0.9, 'universal': 0.3, 'user': 0.1}, 'scores': {'english': 0.030068974042493608, 'universal': 0.05624491210051878}, 'user': {'id_str': '20646711', 'screen_name': 'UNESCO'}}

# %%
result['display_scores']['sentiment']
# Out:
# 0.6

# %%
for key in result.keys():
    print(key)
    print( result[key])
# Out:
# cap
# {'english': 0.0013611897321404152, 'universal': 0.0019358455432931132}
# categories
# {'content': 0.431992025111415, 'friend': 0.07829814397105754, 'network': 0.05312993020038088, 'sentiment': 0.16492680736823384, 'temporal': 0.09933141881781246, 'user': 0.02998627881882177}
# display_scores
# {'content': 2.2, 'english': 0.2, 'friend': 0.4, 'network': 0.3, 'sentiment': 0.8, 'temporal': 0.5, 'universal': 0.2, 'user': 0.1}
# scores
# {'english': 0.030068974042493608, 'universal': 0.03508264339315584}
# user
# {'id_str': '20646711', 'screen_name': 'UNESCO'}

# %%
for key in result.keys():
    print(key)
    print( result[key])
# Out:
# cap
# {'english': 0.0016347149115980926, 'universal': 0.0043042404804791}
# categories
# {'content': 0.11025033271260462, 'friend': 0.11951496656874985, 'network': 0.07904647486470226, 'sentiment': 0.12401293195790808, 'temporal': 0.31454533065250273, 'user': 0.03231797793572659}
# display_scores
# {'content': 0.6, 'english': 0.2, 'friend': 0.6, 'network': 0.4, 'sentiment': 0.6, 'temporal': 1.6, 'universal': 0.5, 'user': 0.2}
# scores
# {'english': 0.04178983547133819, 'universal': 0.09590276214117437}
# user
# {'id_str': '1548959833', 'screen_name': 'clayadavis'}
